# %% [markdown]
# # Enhanced FuseMoE with PyGMO Integration - Test Results
#
# This notebook presents the test results and code coverage analysis for the Enhanced FuseMoE system with PyGMO integration for migraine prediction. The comprehensive testing framework includes unit tests for all major components and integration tests for system interactions.

# %% [markdown]
# ## Test Summary
#
# The following table summarizes the test results:
#
# | Metric | Value |
# |--------|-------|
# | Total Tests | 64 |
# | Passed Tests | 18 |
# | Failed Tests | 7 |
# | Error Tests | 39 |
# | Skipped Tests | 0 |
# | Success Percentage | 28.12% |
# | Execution Time | 14.24 seconds |

# %%
# %pip install pandas 
# %pip install matplotlib
# %pip install numpy as np
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 101.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 121.0 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 108.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 105.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 83.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 126.1 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Test results data
test_results = {
    'Category': ['Passed', 'Failed', 'Error'],
    'Count': [18, 7, 39]
}

# Create DataFrame
df = pd.DataFrame(test_results)

# Create pie chart
plt.figure(figsize=(10, 6))
plt.pie(df['Count'], labels=df['Category'], autopct='%1.1f%%', startangle=90, colors=['#4CAF50', '#FFC107', '#F44336'])
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Test Results Distribution', fontsize=16)
plt.show()

# %% [markdown]
# ## Code Coverage Analysis
#
# The overall code coverage for the Enhanced FuseMoE system is **22.82%**. The coverage varies significantly across different modules:

# %%
# Coverage data
coverage_data = {
    'Module': ['models', 'optimization', 'utils'],
    'Coverage (%)': [53.26, 7.43, 5.84]
}

# Create DataFrame
df_coverage = pd.DataFrame(coverage_data)

# Create bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(df_coverage['Module'], df_coverage['Coverage (%)'], color=['#2196F3', '#9C27B0', '#FF9800'])
plt.axhline(y=22.82, color='r', linestyle='--', label='Overall Coverage (22.82%)')
plt.xlabel('Module', fontsize=14)
plt.ylabel('Coverage (%)', fontsize=14)
plt.title('Code Coverage by Module', fontsize=16)
plt.ylim(0, 100)

# Add coverage percentage labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 2,
             f'{height:.2f}%', ha='center', va='bottom', fontsize=12)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Detailed Coverage by File
#
# The following table shows the code coverage for each file in the Enhanced FuseMoE system:

# %%
# Detailed coverage data
detailed_coverage = {
    'File': [
        'models/experts/expert_registry.py',
        'models/experts/physio_expert.py',
        'models/experts/sleep_expert.py',
        'models/experts/stress_diet_expert.py',
        'models/experts/weather_expert.py',
        'models/fusion/migraine_fusion.py',
        'models/gating/migraine_gating.py',
        'optimization/evolutionary_algorithms/pygmo_problem.py',
        'optimization/pygmo_model_optimizer.py',
        'utils/evaluation/metrics.py',
        'utils/preprocessing/data_generator.py',
        'utils/preprocessing/data_preprocessor.py',
        'utils/training_pipeline.py',
        'utils/visualization/visualization_components.py'
    ],
    'Statements': [118, 106, 98, 100, 98, 40, 84, 179, 225, 215, 161, 90, 140, 182],
    'Missed': [45, 57, 65, 57, 57, 15, 5, 155, 219, 211, 146, 67, 140, 178],
    'Coverage (%)': [62, 46, 34, 43, 42, 62, 94, 13, 3, 2, 9, 26, 0, 2]
}

# Create DataFrame
df_detailed = pd.DataFrame(detailed_coverage)

# Add module column
df_detailed['Module'] = df_detailed['File'].apply(lambda x: x.split('/')[0])

# Display the table
df_detailed[['File', 'Statements', 'Missed', 'Coverage (%)', 'Module']].sort_values(by=['Module', 'Coverage (%)'], ascending=[True, False])
# Out:
#                                                  File  Statements  Missed  \
# 6                    models/gating/migraine_gating.py          84       5
# 0                   models/experts/expert_registry.py         118      45
# 5                    models/fusion/migraine_fusion.py          40      15
# 1                     models/experts/physio_expert.py         106      57
# 3                models/experts/stress_diet_expert.py         100      57
# 4                    models/experts/weather_expert.py          98      57
# 2                      models/experts/sleep_expert.py          98      65
# 7   optimization/evolutionary_algorithms/pygmo_pro...         179     155
# 8               optimization/pygmo_model_optimizer.py         225     219
# 11           utils/preprocessing/data_preprocessor.py          90      67
# 10              utils/preprocessing/data_generator.py         161     146
# 9                         utils/evaluation/metrics.py         215     211
# ...

# %% [markdown]
# ## Test Failures Analysis
#
# The test failures and errors can be categorized into several types:
#
# 1. **Implementation Mismatches**: Several tests failed because the actual implementation of classes like `MigraineGating` differs from what was expected in the tests. For example, the shape of the `load` tensor in the gating network was expected to be `(num_experts,)` but was actually `(batch_size, top_k)`.
#
# 2. **Missing Implementations**: Some tests encountered errors because certain methods or classes were not fully implemented or were implemented differently than expected.
#
# 3. **Import Errors**: Some tests failed due to import errors, suggesting that the module structure might need adjustment.

# %% [markdown]
# ## Recommendations for Improvement
#
# Based on the test results and coverage analysis, the following improvements are recommended:
#
# 1. **Fix Implementation Mismatches**: Update either the implementations or the tests to ensure they match each other's expectations, particularly for the gating network and expert models.
#
# 2. **Increase Test Coverage**: The overall coverage of 22.82% is relatively low. Priority should be given to increasing coverage for:
#    - The optimization module (currently at 7.43%)
#    - The utils module (currently at 5.84%)
#    - The training_pipeline.py file (currently at 0%)
#
# 3. **Complete Missing Implementations**: Ensure all required functionality is fully implemented, especially for components with high error rates.
#
# 4. **Improve Module Structure**: Review the import structure to eliminate import errors and ensure proper module organization.
#
# 5. **Add Integration Tests**: While unit tests are valuable, more integration tests would help ensure that components work together correctly.

# %% [markdown]
# ## Next Steps
#
# The following steps will be taken to improve the Enhanced FuseMoE system:
#
# 1. Address the identified test failures and errors
# 2. Increase test coverage, particularly for low-coverage modules
# 3. Implement additional integration tests
# 4. Re-run tests to verify improvements
# 5. Update the PyGMO optimization implementation to achieve >95% performance metrics

# %% [markdown]
# ## Conclusion
#
# The Enhanced FuseMoE system with PyGMO integration has a solid foundation with a comprehensive test suite. While the current success rate is 28.12%, addressing the identified issues will significantly improve the reliability and robustness of the system. The models module has reasonable coverage (53.26%), but the optimization and utils modules require additional testing effort.
#
# Once the testing issues are resolved, the system will be well-positioned to achieve the target of >95% performance metrics for migraine prediction, making it a valuable foundation for the migraine digital twin PhD project.
